# %%
import sys
sys.path.append('../')


from asteroids.asteroid_data import *

# %%
data = AsteroidData("2023-07-01", "2023-07-03").get_data_from_nasa(save_to_file=True)

# %%
AsteroidData()._get_local_data("/workspaces/Asteroids/assets/json/nasa_json.json")
# Out:
# {'links': None,
#  'element_count': 27,
#  'near_earth_objects': {'2023-07-01': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2385423?api_key=5I2GBzwApJeBHWvduK4oqoWGH94D4c5b3IzVOo0b'},
#     'id': '2385423',
#     'neo_reference_id': '2385423',
#     'name': '385423 (2003 DE6)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2385423',
#     'absolute_magnitude_h': 19.25,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3754524794,
#       'estimated_diameter_max': 0.8395372662},
#      'meters': {'estimated_diameter_min': 375.4524793607,
#       'estimated_diameter_max': 839.5372661714},
#      'miles': {'estimated_diameter_min': 0.2332952826,
#       'estimated_diameter_max': 0.5216641106},
#      'feet': {'estimated_diameter_min': 1231.7995123859,
#       'estimated_diameter_max': 2754.3874443459}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2023-07-01',
# ...
